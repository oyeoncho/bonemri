# %%
import os
import SimpleITK as sitk
import numpy as np

image_dir = "./image_data/images"
mask_dir = "./image_data/masks"
output_image_dir = "./image_data/output_224/images"
output_mask_dir = "./image_data/output_224/masks"
cache_dir = "./image_data/n4_cache"

os.makedirs(output_image_dir, exist_ok=True)
os.makedirs(output_mask_dir, exist_ok=True)
os.makedirs(cache_dir, exist_ok=True)

# ⚙️ 기준 spacing 및 shape (골반 전체 포함하도록 확대)
TARGET_SPACING = [1.0, 1.0, 1.0]
TARGET_SHAPE = (128, 224, 224)


# ✅ Bias field correction with caching
def bias_field_correction_cached(image, fname):
    cached_path = os.path.join(cache_dir, fname)
    if os.path.exists(cached_path):
        print(f"⚡ Using cached bias corrected: {fname}")
        return sitk.ReadImage(cached_path)

    image = sitk.Cast(image, sitk.sitkFloat32)
    mask = sitk.OtsuThreshold(image, 0, 1, 200)
    corrector = sitk.N4BiasFieldCorrectionImageFilter()
    corrected = corrector.Execute(image, mask)
    sitk.WriteImage(corrected, cached_path)
    print(f"✅ Cached bias corrected: {fname}")
    return corrected

# ✅ Z-score normalization
def normalize_image(itk_image):
    image_np = sitk.GetArrayFromImage(itk_image).astype(np.float32)
    nonzero = image_np[image_np > 0]
    if nonzero.size == 0:
        return itk_image
    mean, std = np.mean(nonzero), np.std(nonzero)
    normalized = (image_np - mean) / (std + 1e-8)
    normalized[image_np == 0] = 0
    norm_image = sitk.GetImageFromArray(normalized.astype(np.float32))
    norm_image.CopyInformation(itk_image)
    return norm_image

# ✅ Resampling
def resample_image(itk_image, is_label=False):
    original_spacing = itk_image.GetSpacing()
    original_size = itk_image.GetSize()
    new_size = [
        int(round(osz * ospc / tspc))
        for osz, ospc, tspc in zip(original_size, original_spacing, TARGET_SPACING)
    ]
    resampler = sitk.ResampleImageFilter()
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    resampler.SetOutputSpacing(TARGET_SPACING)
    resampler.SetSize(new_size)
    resampler.SetOutputDirection(itk_image.GetDirection())
    resampler.SetOutputOrigin(itk_image.GetOrigin())
    resampler.SetDefaultPixelValue(0)
    return resampler.Execute(itk_image)

# ✅ Padding or cropping
def pad_or_crop(image_np, target_shape):
    current_shape = image_np.shape
    pad_width = [(0, max(t - c, 0)) for c, t in zip(current_shape, target_shape)]
    padded = np.pad(image_np, pad_width, mode='constant')
    cropped = padded[:target_shape[0], :target_shape[1], :target_shape[2]]
    return cropped

# 🔁 메인 루프
for fname in sorted(os.listdir(image_dir)):
    if not fname.endswith(".nii.gz") or fname in exclude_files:
        continue

    image_path = os.path.join(image_dir, fname)
    mask_path = os.path.join(mask_dir, fname)

    if not os.path.exists(mask_path):
        print(f"❌ Mask not found for {fname}")
        continue

    try:
        print(f"🔧 Processing: {fname}")

        # 1. Load
        image = sitk.ReadImage(image_path)
        mask = sitk.ReadImage(mask_path)

        # 2. Bias field correction (with cache)
        image = bias_field_correction_cached(image, fname)

        # 3. Z-score normalization
        image = normalize_image(image)

        # 4. Resample
        image_resampled = resample_image(image, is_label=False)
        mask_resampled = resample_image(mask, is_label=True)

        # 5. Pad or crop
        image_np = sitk.GetArrayFromImage(image_resampled).astype(np.float32)
        mask_np = sitk.GetArrayFromImage(mask_resampled).astype(np.uint8)

        image_fixed = pad_or_crop(image_np, TARGET_SHAPE)
        mask_fixed = pad_or_crop(mask_np, TARGET_SHAPE)

        # 6. Convert back to image
        image_out = sitk.GetImageFromArray(image_fixed)
        mask_out = sitk.GetImageFromArray(mask_fixed)

        # 7. Set metadata
        image_out.SetSpacing(TARGET_SPACING)
        image_out.SetOrigin(image_resampled.GetOrigin())
        image_out.SetDirection(image_resampled.GetDirection())

        mask_out.SetSpacing(TARGET_SPACING)
        mask_out.SetOrigin(image_resampled.GetOrigin())
        mask_out.SetDirection(image_resampled.GetDirection())

        # 8. Save
        sitk.WriteImage(image_out, os.path.join(output_image_dir, fname))
        sitk.WriteImage(mask_out, os.path.join(output_mask_dir, fname))
        print(f"✅ Done: {fname}")

    except Exception as e:
        print(f"❌ Failed {fname}: {e}")
# Out:
# 🔧 Processing: P001_post_0000.nii.gz
# ⚡ Using cached bias corrected: P001_post_0000.nii.gz
# ✅ Done: P001_post_0000.nii.gz
# 🔧 Processing: P001_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P001_pre_0000.nii.gz
# ✅ Done: P001_pre_0000.nii.gz
# 🔧 Processing: P002_post_0000.nii.gz
# ⚡ Using cached bias corrected: P002_post_0000.nii.gz
# ✅ Done: P002_post_0000.nii.gz
# 🔧 Processing: P002_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P002_pre_0000.nii.gz
# ✅ Done: P002_pre_0000.nii.gz
# 🔧 Processing: P003_post_0000.nii.gz
# ⚡ Using cached bias corrected: P003_post_0000.nii.gz
# ✅ Done: P003_post_0000.nii.gz
# 🔧 Processing: P003_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P003_pre_0000.nii.gz
# ✅ Done: P003_pre_0000.nii.gz
# 🔧 Processing: P004_post_0000.nii.gz
# ⚡ Using cached bias corrected: P004_post_0000.nii.gz
# ✅ Done: P004_post_0000.nii.gz
# 🔧 Processing: P004_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P004_pre_0000.nii.gz
# ✅ Done: P004_pre_0000.nii.gz
# 🔧 Processing: P005_post_0000.nii.gz
# ⚡ Using cached bias corrected: P005_post_0000.nii.gz
# ✅ Done: P005_post_0000.nii.gz
# 🔧 Processing: P005_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P005_pre_0000.nii.gz
# ✅ Done: P005_pre_0000.nii.gz
# 🔧 Processing: P006_post_0000.nii.gz
# ⚡ Using cached bias corrected: P006_post_0000.nii.gz
# ✅ Done: P006_post_0000.nii.gz
# 🔧 Processing: P006_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P006_pre_0000.nii.gz
# ✅ Done: P006_pre_0000.nii.gz
# 🔧 Processing: P007_post_0000.nii.gz
# ⚡ Using cached bias corrected: P007_post_0000.nii.gz
# ✅ Done: P007_post_0000.nii.gz
# 🔧 Processing: P007_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P007_pre_0000.nii.gz
# ✅ Done: P007_pre_0000.nii.gz
# 🔧 Processing: P008_post_0000.nii.gz
# ⚡ Using cached bias corrected: P008_post_0000.nii.gz
# ✅ Done: P008_post_0000.nii.gz
# 🔧 Processing: P008_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P008_pre_0000.nii.gz
# ✅ Done: P008_pre_0000.nii.gz
# 🔧 Processing: P009_post_0000.nii.gz
# ⚡ Using cached bias corrected: P009_post_0000.nii.gz
# ✅ Done: P009_post_0000.nii.gz
# 🔧 Processing: P009_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P009_pre_0000.nii.gz
# ✅ Done: P009_pre_0000.nii.gz
# 🔧 Processing: P010_post_0000.nii.gz
# ⚡ Using cached bias corrected: P010_post_0000.nii.gz
# ✅ Done: P010_post_0000.nii.gz
# 🔧 Processing: P010_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P010_pre_0000.nii.gz
# ✅ Done: P010_pre_0000.nii.gz
# 🔧 Processing: P011_post_0000.nii.gz
# ⚡ Using cached bias corrected: P011_post_0000.nii.gz
# ✅ Done: P011_post_0000.nii.gz
# 🔧 Processing: P011_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P011_pre_0000.nii.gz
# ✅ Done: P011_pre_0000.nii.gz
# 🔧 Processing: P012_post_0000.nii.gz
# ⚡ Using cached bias corrected: P012_post_0000.nii.gz
# ✅ Done: P012_post_0000.nii.gz
# 🔧 Processing: P012_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P012_pre_0000.nii.gz
# ✅ Done: P012_pre_0000.nii.gz
# 🔧 Processing: P013_post_0000.nii.gz
# ⚡ Using cached bias corrected: P013_post_0000.nii.gz
# ✅ Done: P013_post_0000.nii.gz
# 🔧 Processing: P013_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P013_pre_0000.nii.gz
# ✅ Done: P013_pre_0000.nii.gz
# 🔧 Processing: P014_post_0000.nii.gz
# ⚡ Using cached bias corrected: P014_post_0000.nii.gz
# ✅ Done: P014_post_0000.nii.gz
# 🔧 Processing: P014_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P014_pre_0000.nii.gz
# ✅ Done: P014_pre_0000.nii.gz
# 🔧 Processing: P015_post_0000.nii.gz
# ⚡ Using cached bias corrected: P015_post_0000.nii.gz
# ✅ Done: P015_post_0000.nii.gz
# 🔧 Processing: P015_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P015_pre_0000.nii.gz
# ✅ Done: P015_pre_0000.nii.gz
# 🔧 Processing: P016_post_0000.nii.gz
# ⚡ Using cached bias corrected: P016_post_0000.nii.gz
# ✅ Done: P016_post_0000.nii.gz
# 🔧 Processing: P016_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P016_pre_0000.nii.gz
# ✅ Done: P016_pre_0000.nii.gz
# 🔧 Processing: P017_post_0000.nii.gz
# ⚡ Using cached bias corrected: P017_post_0000.nii.gz
# ✅ Done: P017_post_0000.nii.gz
# 🔧 Processing: P017_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P017_pre_0000.nii.gz
# ✅ Done: P017_pre_0000.nii.gz
# 🔧 Processing: P018_post_0000.nii.gz
# ⚡ Using cached bias corrected: P018_post_0000.nii.gz
# ✅ Done: P018_post_0000.nii.gz
# 🔧 Processing: P018_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P018_pre_0000.nii.gz
# ✅ Done: P018_pre_0000.nii.gz
# 🔧 Processing: P019_post_0000.nii.gz
# ⚡ Using cached bias corrected: P019_post_0000.nii.gz
# ✅ Done: P019_post_0000.nii.gz
# 🔧 Processing: P019_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P019_pre_0000.nii.gz
# ✅ Done: P019_pre_0000.nii.gz
# 🔧 Processing: P020_post_0000.nii.gz
# ⚡ Using cached bias corrected: P020_post_0000.nii.gz
# ✅ Done: P020_post_0000.nii.gz
# 🔧 Processing: P020_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P020_pre_0000.nii.gz
# ✅ Done: P020_pre_0000.nii.gz
# 🔧 Processing: P021_post_0000.nii.gz
# ⚡ Using cached bias corrected: P021_post_0000.nii.gz
# ✅ Done: P021_post_0000.nii.gz
# 🔧 Processing: P021_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P021_pre_0000.nii.gz
# ✅ Done: P021_pre_0000.nii.gz
# 🔧 Processing: P022_post_0000.nii.gz
# ⚡ Using cached bias corrected: P022_post_0000.nii.gz
# ✅ Done: P022_post_0000.nii.gz
# 🔧 Processing: P022_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P022_pre_0000.nii.gz
# ✅ Done: P022_pre_0000.nii.gz
# 🔧 Processing: P023_post_0000.nii.gz
# ⚡ Using cached bias corrected: P023_post_0000.nii.gz
# ✅ Done: P023_post_0000.nii.gz
# 🔧 Processing: P023_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P023_pre_0000.nii.gz
# ✅ Done: P023_pre_0000.nii.gz
# 🔧 Processing: P024_post_0000.nii.gz
# ⚡ Using cached bias corrected: P024_post_0000.nii.gz
# ✅ Done: P024_post_0000.nii.gz
# 🔧 Processing: P024_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P024_pre_0000.nii.gz
# ✅ Done: P024_pre_0000.nii.gz
# 🔧 Processing: P025_post_0000.nii.gz
# ⚡ Using cached bias corrected: P025_post_0000.nii.gz
# ✅ Done: P025_post_0000.nii.gz
# 🔧 Processing: P025_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P025_pre_0000.nii.gz
# ✅ Done: P025_pre_0000.nii.gz
# 🔧 Processing: P026_post_0000.nii.gz
# ⚡ Using cached bias corrected: P026_post_0000.nii.gz
# ✅ Done: P026_post_0000.nii.gz
# 🔧 Processing: P026_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P026_pre_0000.nii.gz
# ✅ Done: P026_pre_0000.nii.gz
# 🔧 Processing: P027_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P027_pre_0000.nii.gz
# ✅ Done: P027_pre_0000.nii.gz
# 🔧 Processing: P028_post_0000.nii.gz
# ⚡ Using cached bias corrected: P028_post_0000.nii.gz
# ✅ Done: P028_post_0000.nii.gz
# 🔧 Processing: P028_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P028_pre_0000.nii.gz
# ✅ Done: P028_pre_0000.nii.gz
# 🔧 Processing: P029_post_0000.nii.gz
# ⚡ Using cached bias corrected: P029_post_0000.nii.gz
# ✅ Done: P029_post_0000.nii.gz
# 🔧 Processing: P029_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P029_pre_0000.nii.gz
# ✅ Done: P029_pre_0000.nii.gz
# 🔧 Processing: P030_post_0000.nii.gz
# ⚡ Using cached bias corrected: P030_post_0000.nii.gz
# ✅ Done: P030_post_0000.nii.gz
# 🔧 Processing: P030_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P030_pre_0000.nii.gz
# ✅ Done: P030_pre_0000.nii.gz
# 🔧 Processing: P031_post_0000.nii.gz
# ⚡ Using cached bias corrected: P031_post_0000.nii.gz
# ✅ Done: P031_post_0000.nii.gz
# 🔧 Processing: P031_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P031_pre_0000.nii.gz
# ✅ Done: P031_pre_0000.nii.gz
# 🔧 Processing: P032_post_0000.nii.gz
# ⚡ Using cached bias corrected: P032_post_0000.nii.gz
# ✅ Done: P032_post_0000.nii.gz
# 🔧 Processing: P032_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P032_pre_0000.nii.gz
# ✅ Done: P032_pre_0000.nii.gz
# 🔧 Processing: P033_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P033_pre_0000.nii.gz
# ✅ Done: P033_pre_0000.nii.gz
# 🔧 Processing: P034_post_0000.nii.gz
# ⚡ Using cached bias corrected: P034_post_0000.nii.gz
# ✅ Done: P034_post_0000.nii.gz
# 🔧 Processing: P034_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P034_pre_0000.nii.gz
# ✅ Done: P034_pre_0000.nii.gz
# 🔧 Processing: P035_post_0000.nii.gz
# ⚡ Using cached bias corrected: P035_post_0000.nii.gz
# ✅ Done: P035_post_0000.nii.gz
# 🔧 Processing: P035_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P035_pre_0000.nii.gz
# ✅ Done: P035_pre_0000.nii.gz
# 🔧 Processing: P036_post_0000.nii.gz
# ⚡ Using cached bias corrected: P036_post_0000.nii.gz
# ✅ Done: P036_post_0000.nii.gz
# 🔧 Processing: P036_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P036_pre_0000.nii.gz
# ✅ Done: P036_pre_0000.nii.gz
# 🔧 Processing: P037_post_0000.nii.gz
# ⚡ Using cached bias corrected: P037_post_0000.nii.gz
# ✅ Done: P037_post_0000.nii.gz
# 🔧 Processing: P037_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P037_pre_0000.nii.gz
# ✅ Done: P037_pre_0000.nii.gz
# 🔧 Processing: P038_post_0000.nii.gz
# ⚡ Using cached bias corrected: P038_post_0000.nii.gz
# ✅ Done: P038_post_0000.nii.gz
# 🔧 Processing: P038_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P038_pre_0000.nii.gz
# ✅ Done: P038_pre_0000.nii.gz
# 🔧 Processing: P039_post_0000.nii.gz
# ⚡ Using cached bias corrected: P039_post_0000.nii.gz
# ✅ Done: P039_post_0000.nii.gz
# 🔧 Processing: P039_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P039_pre_0000.nii.gz
# ✅ Done: P039_pre_0000.nii.gz
# 🔧 Processing: P040_post_0000.nii.gz
# ⚡ Using cached bias corrected: P040_post_0000.nii.gz
# ✅ Done: P040_post_0000.nii.gz
# 🔧 Processing: P040_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P040_pre_0000.nii.gz
# ✅ Done: P040_pre_0000.nii.gz
# 🔧 Processing: P041_post_0000.nii.gz
# ⚡ Using cached bias corrected: P041_post_0000.nii.gz
# ✅ Done: P041_post_0000.nii.gz
# 🔧 Processing: P041_pre_0000.nii.gz
# ⚡ Using cached bias corrected: P041_pre_0000.nii.gz
# ✅ Done: P041_pre_0000.nii.gz
# 🔧 Processing: P042_post_0000.nii.gz
# ⚡ Using cached bias corrected: P042_post_0000.nii.gz
# ✅ Done: P042_post_0000.nii.gz
# 🔧 Processing: VP001_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP001_pre_0000.nii.gz
# ✅ Done: VP001_pre_0000.nii.gz
# 🔧 Processing: VP002_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP002_pre_0000.nii.gz
# ✅ Done: VP002_pre_0000.nii.gz
# 🔧 Processing: VP005_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP005_pre_0000.nii.gz
# ✅ Done: VP005_pre_0000.nii.gz
# 🔧 Processing: VP006_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP006_pre_0000.nii.gz
# ✅ Done: VP006_pre_0000.nii.gz
# 🔧 Processing: VP007_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP007_pre_0000.nii.gz
# ✅ Done: VP007_pre_0000.nii.gz
# 🔧 Processing: VP011_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP011_pre_0000.nii.gz
# ✅ Done: VP011_pre_0000.nii.gz
# 🔧 Processing: VP012_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP012_pre_0000.nii.gz
# ✅ Done: VP012_pre_0000.nii.gz
# 🔧 Processing: VP013_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP013_pre_0000.nii.gz
# ✅ Done: VP013_pre_0000.nii.gz
# 🔧 Processing: VP014_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP014_pre_0000.nii.gz
# ✅ Done: VP014_pre_0000.nii.gz
# 🔧 Processing: VP015_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP015_pre_0000.nii.gz
# ✅ Done: VP015_pre_0000.nii.gz
# 🔧 Processing: VP016_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP016_pre_0000.nii.gz
# ✅ Done: VP016_pre_0000.nii.gz
# 🔧 Processing: VP017_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP017_pre_0000.nii.gz
# ✅ Done: VP017_pre_0000.nii.gz
# 🔧 Processing: VP018_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP018_pre_0000.nii.gz
# ✅ Done: VP018_pre_0000.nii.gz
# 🔧 Processing: VP019_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP019_pre_0000.nii.gz
# ✅ Done: VP019_pre_0000.nii.gz
# 🔧 Processing: VP021_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP021_pre_0000.nii.gz
# ✅ Done: VP021_pre_0000.nii.gz
# 🔧 Processing: VP022_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP022_pre_0000.nii.gz
# ✅ Done: VP022_pre_0000.nii.gz
# 🔧 Processing: VP023_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP023_pre_0000.nii.gz
# ✅ Done: VP023_pre_0000.nii.gz
# 🔧 Processing: VP024_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP024_pre_0000.nii.gz
# ✅ Done: VP024_pre_0000.nii.gz
# 🔧 Processing: VP025_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP025_pre_0000.nii.gz
# ✅ Done: VP025_pre_0000.nii.gz
# 🔧 Processing: VP026_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP026_pre_0000.nii.gz
# ✅ Done: VP026_pre_0000.nii.gz
# 🔧 Processing: VP027_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP027_pre_0000.nii.gz
# ✅ Done: VP027_pre_0000.nii.gz
# 🔧 Processing: VP028_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP028_pre_0000.nii.gz
# ✅ Done: VP028_pre_0000.nii.gz
# 🔧 Processing: VP030_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP030_pre_0000.nii.gz
# ✅ Done: VP030_pre_0000.nii.gz
# 🔧 Processing: VP031_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP031_pre_0000.nii.gz
# ✅ Done: VP031_pre_0000.nii.gz
# 🔧 Processing: VP032_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP032_pre_0000.nii.gz
# ✅ Done: VP032_pre_0000.nii.gz
# 🔧 Processing: VP033_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP033_pre_0000.nii.gz
# ✅ Done: VP033_pre_0000.nii.gz
# 🔧 Processing: VP034_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP034_post_0000.nii.gz
# ✅ Done: VP034_post_0000.nii.gz
# 🔧 Processing: VP034_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP034_pre_0000.nii.gz
# ✅ Done: VP034_pre_0000.nii.gz
# 🔧 Processing: VP035_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP035_pre_0000.nii.gz
# ✅ Done: VP035_pre_0000.nii.gz
# 🔧 Processing: VP037_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP037_pre_0000.nii.gz
# ✅ Done: VP037_pre_0000.nii.gz
# 🔧 Processing: VP038_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP038_pre_0000.nii.gz
# ✅ Done: VP038_pre_0000.nii.gz
# 🔧 Processing: VP039_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP039_pre_0000.nii.gz
# ✅ Done: VP039_pre_0000.nii.gz
# 🔧 Processing: VP040_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP040_pre_0000.nii.gz
# ✅ Done: VP040_pre_0000.nii.gz
# 🔧 Processing: VP041_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP041_pre_0000.nii.gz
# ✅ Done: VP041_pre_0000.nii.gz
# 🔧 Processing: VP042_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP042_pre_0000.nii.gz
# ✅ Done: VP042_pre_0000.nii.gz
# 🔧 Processing: VP043_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP043_pre_0000.nii.gz
# ✅ Done: VP043_pre_0000.nii.gz
# 🔧 Processing: VP044_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP044_pre_0000.nii.gz
# ✅ Done: VP044_pre_0000.nii.gz
# 🔧 Processing: VP045_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP045_pre_0000.nii.gz
# ✅ Done: VP045_pre_0000.nii.gz
# 🔧 Processing: VP046_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP046_pre_0000.nii.gz
# ✅ Done: VP046_pre_0000.nii.gz
# 🔧 Processing: VP047_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP047_pre_0000.nii.gz
# ✅ Done: VP047_pre_0000.nii.gz
# 🔧 Processing: VP048_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP048_pre_0000.nii.gz
# ✅ Done: VP048_pre_0000.nii.gz
# 🔧 Processing: VP049_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP049_pre_0000.nii.gz
# ✅ Done: VP049_pre_0000.nii.gz
# 🔧 Processing: VP051_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP051_pre_0000.nii.gz
# ✅ Done: VP051_pre_0000.nii.gz
# 🔧 Processing: VP052_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP052_pre_0000.nii.gz
# ✅ Done: VP052_pre_0000.nii.gz
# 🔧 Processing: VP053_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP053_pre_0000.nii.gz
# ✅ Done: VP053_pre_0000.nii.gz
# 🔧 Processing: VP054_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP054_pre_0000.nii.gz
# ✅ Done: VP054_pre_0000.nii.gz
# 🔧 Processing: VP055_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP055_pre_0000.nii.gz
# ✅ Done: VP055_pre_0000.nii.gz
# 🔧 Processing: VP056_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP056_pre_0000.nii.gz
# ✅ Done: VP056_pre_0000.nii.gz
# 🔧 Processing: VP057_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP057_pre_0000.nii.gz
# ✅ Done: VP057_pre_0000.nii.gz
# 🔧 Processing: VP058_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP058_pre_0000.nii.gz
# ✅ Done: VP058_pre_0000.nii.gz
# 🔧 Processing: VP059_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP059_pre_0000.nii.gz
# ✅ Done: VP059_pre_0000.nii.gz
# 🔧 Processing: VP060_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP060_pre_0000.nii.gz
# ✅ Done: VP060_pre_0000.nii.gz
# 🔧 Processing: VP062_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP062_pre_0000.nii.gz
# ✅ Done: VP062_pre_0000.nii.gz
# 🔧 Processing: VP063_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP063_pre_0000.nii.gz
# ✅ Done: VP063_pre_0000.nii.gz
# 🔧 Processing: VP064_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP064_pre_0000.nii.gz
# ✅ Done: VP064_pre_0000.nii.gz
# 🔧 Processing: VP065_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP065_pre_0000.nii.gz
# ✅ Done: VP065_pre_0000.nii.gz
# 🔧 Processing: VP066_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP066_pre_0000.nii.gz
# ✅ Done: VP066_pre_0000.nii.gz
# 🔧 Processing: VP067_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP067_pre_0000.nii.gz
# ✅ Done: VP067_pre_0000.nii.gz
# 🔧 Processing: VP068_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP068_pre_0000.nii.gz
# ✅ Done: VP068_pre_0000.nii.gz
# 🔧 Processing: VP069_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP069_pre_0000.nii.gz
# ✅ Done: VP069_pre_0000.nii.gz
# 🔧 Processing: VP070_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP070_pre_0000.nii.gz
# ✅ Done: VP070_pre_0000.nii.gz
# 🔧 Processing: VP071_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP071_pre_0000.nii.gz
# ✅ Done: VP071_pre_0000.nii.gz
# 🔧 Processing: VP072_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP072_pre_0000.nii.gz
# ✅ Done: VP072_pre_0000.nii.gz
# 🔧 Processing: VP073_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP073_pre_0000.nii.gz
# ✅ Done: VP073_pre_0000.nii.gz
# 🔧 Processing: VP074_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP074_post_0000.nii.gz
# ✅ Done: VP074_post_0000.nii.gz
# 🔧 Processing: VP074_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP074_pre_0000.nii.gz
# ✅ Done: VP074_pre_0000.nii.gz
# 🔧 Processing: VP075_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP075_pre_0000.nii.gz
# ✅ Done: VP075_pre_0000.nii.gz
# 🔧 Processing: VP076_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP076_pre_0000.nii.gz
# ✅ Done: VP076_pre_0000.nii.gz
# 🔧 Processing: VP078_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP078_pre_0000.nii.gz
# ✅ Done: VP078_pre_0000.nii.gz
# 🔧 Processing: VP079_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP079_pre_0000.nii.gz
# ✅ Done: VP079_pre_0000.nii.gz
# 🔧 Processing: VP080_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP080_pre_0000.nii.gz
# ✅ Done: VP080_pre_0000.nii.gz
# 🔧 Processing: VP081_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP081_pre_0000.nii.gz
# ✅ Done: VP081_pre_0000.nii.gz
# 🔧 Processing: VP082_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP082_pre_0000.nii.gz
# ✅ Done: VP082_pre_0000.nii.gz
# 🔧 Processing: VP083_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP083_pre_0000.nii.gz
# ✅ Done: VP083_pre_0000.nii.gz
# 🔧 Processing: VP084_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP084_post_0000.nii.gz
# ✅ Done: VP084_post_0000.nii.gz
# 🔧 Processing: VP084_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP084_pre_0000.nii.gz
# ✅ Done: VP084_pre_0000.nii.gz
# 🔧 Processing: VP085_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP085_pre_0000.nii.gz
# ✅ Done: VP085_pre_0000.nii.gz
# 🔧 Processing: VP086_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP086_pre_0000.nii.gz
# ✅ Done: VP086_pre_0000.nii.gz
# 🔧 Processing: VP087_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP087_pre_0000.nii.gz
# ✅ Done: VP087_pre_0000.nii.gz
# 🔧 Processing: VP088_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP088_pre_0000.nii.gz
# ✅ Done: VP088_pre_0000.nii.gz
# 🔧 Processing: VP089_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP089_pre_0000.nii.gz
# ✅ Done: VP089_pre_0000.nii.gz
# 🔧 Processing: VP090_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP090_pre_0000.nii.gz
# ✅ Done: VP090_pre_0000.nii.gz
# 🔧 Processing: VP091_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP091_pre_0000.nii.gz
# ✅ Done: VP091_pre_0000.nii.gz
# 🔧 Processing: VP092_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP092_pre_0000.nii.gz
# ✅ Done: VP092_pre_0000.nii.gz
# 🔧 Processing: VP093_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP093_pre_0000.nii.gz
# ✅ Done: VP093_pre_0000.nii.gz
# 🔧 Processing: VP094_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP094_pre_0000.nii.gz
# ✅ Done: VP094_pre_0000.nii.gz
# 🔧 Processing: VP095_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP095_pre_0000.nii.gz
# ✅ Done: VP095_pre_0000.nii.gz
# 🔧 Processing: VP096_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP096_pre_0000.nii.gz
# ✅ Done: VP096_pre_0000.nii.gz
# 🔧 Processing: VP097_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP097_pre_0000.nii.gz
# ✅ Done: VP097_pre_0000.nii.gz
# 🔧 Processing: VP098_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP098_pre_0000.nii.gz
# ✅ Done: VP098_pre_0000.nii.gz
# 🔧 Processing: VP099_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP099_pre_0000.nii.gz
# ✅ Done: VP099_pre_0000.nii.gz
# 🔧 Processing: VP100_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP100_pre_0000.nii.gz
# ✅ Done: VP100_pre_0000.nii.gz
# 🔧 Processing: VP101_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP101_pre_0000.nii.gz
# ✅ Done: VP101_pre_0000.nii.gz
# 🔧 Processing: VP102_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP102_pre_0000.nii.gz
# ✅ Done: VP102_pre_0000.nii.gz
# 🔧 Processing: VP103_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP103_pre_0000.nii.gz
# ✅ Done: VP103_pre_0000.nii.gz
# 🔧 Processing: VP104_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP104_post_0000.nii.gz
# ✅ Done: VP104_post_0000.nii.gz
# 🔧 Processing: VP104_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP104_pre_0000.nii.gz
# ✅ Done: VP104_pre_0000.nii.gz
# 🔧 Processing: VP105_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP105_pre_0000.nii.gz
# ✅ Done: VP105_pre_0000.nii.gz
# 🔧 Processing: VP107_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP107_pre_0000.nii.gz
# ✅ Done: VP107_pre_0000.nii.gz
# 🔧 Processing: VP108_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP108_pre_0000.nii.gz
# ✅ Done: VP108_pre_0000.nii.gz
# 🔧 Processing: VP109_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP109_pre_0000.nii.gz
# ✅ Done: VP109_pre_0000.nii.gz
# 🔧 Processing: VP110_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP110_pre_0000.nii.gz
# ✅ Done: VP110_pre_0000.nii.gz
# 🔧 Processing: VP111_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP111_post_0000.nii.gz
# ✅ Done: VP111_post_0000.nii.gz
# 🔧 Processing: VP111_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP111_pre_0000.nii.gz
# ✅ Done: VP111_pre_0000.nii.gz
# 🔧 Processing: VP112_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP112_pre_0000.nii.gz
# ✅ Done: VP112_pre_0000.nii.gz
# 🔧 Processing: VP113_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP113_pre_0000.nii.gz
# ✅ Done: VP113_pre_0000.nii.gz
# 🔧 Processing: VP114_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP114_pre_0000.nii.gz
# ✅ Done: VP114_pre_0000.nii.gz
# 🔧 Processing: VP115_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP115_pre_0000.nii.gz
# ✅ Done: VP115_pre_0000.nii.gz
# 🔧 Processing: VP116_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP116_pre_0000.nii.gz
# ✅ Done: VP116_pre_0000.nii.gz
# 🔧 Processing: VP117_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP117_post_0000.nii.gz
# ✅ Done: VP117_post_0000.nii.gz
# 🔧 Processing: VP117_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP117_pre_0000.nii.gz
# ✅ Done: VP117_pre_0000.nii.gz
# 🔧 Processing: VP118_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP118_pre_0000.nii.gz
# ✅ Done: VP118_pre_0000.nii.gz
# 🔧 Processing: VP119_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP119_pre_0000.nii.gz
# ✅ Done: VP119_pre_0000.nii.gz
# 🔧 Processing: VP120_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP120_post_0000.nii.gz
# ✅ Done: VP120_post_0000.nii.gz
# 🔧 Processing: VP120_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP120_pre_0000.nii.gz
# ✅ Done: VP120_pre_0000.nii.gz
# 🔧 Processing: VP121_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP121_pre_0000.nii.gz
# ✅ Done: VP121_pre_0000.nii.gz
# 🔧 Processing: VP122_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP122_pre_0000.nii.gz
# ✅ Done: VP122_pre_0000.nii.gz
# 🔧 Processing: VP123_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP123_pre_0000.nii.gz
# ✅ Done: VP123_pre_0000.nii.gz
# 🔧 Processing: VP124_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP124_pre_0000.nii.gz
# ✅ Done: VP124_pre_0000.nii.gz
# 🔧 Processing: VP125_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP125_post_0000.nii.gz
# ✅ Done: VP125_post_0000.nii.gz
# 🔧 Processing: VP125_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP125_pre_0000.nii.gz
# ✅ Done: VP125_pre_0000.nii.gz
# 🔧 Processing: VP126_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP126_pre_0000.nii.gz
# ✅ Done: VP126_pre_0000.nii.gz
# 🔧 Processing: VP127_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP127_pre_0000.nii.gz
# ✅ Done: VP127_pre_0000.nii.gz
# 🔧 Processing: VP128_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP128_post_0000.nii.gz
# ✅ Done: VP128_post_0000.nii.gz
# 🔧 Processing: VP128_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP128_pre_0000.nii.gz
# ✅ Done: VP128_pre_0000.nii.gz
# 🔧 Processing: VP129_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP129_post_0000.nii.gz
# ✅ Done: VP129_post_0000.nii.gz
# 🔧 Processing: VP129_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP129_pre_0000.nii.gz
# ✅ Done: VP129_pre_0000.nii.gz
# 🔧 Processing: VP130_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP130_post_0000.nii.gz
# ✅ Done: VP130_post_0000.nii.gz
# 🔧 Processing: VP130_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP130_pre_0000.nii.gz
# ✅ Done: VP130_pre_0000.nii.gz
# 🔧 Processing: VP131_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP131_pre_0000.nii.gz
# ✅ Done: VP131_pre_0000.nii.gz
# 🔧 Processing: VP132_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP132_pre_0000.nii.gz
# ✅ Done: VP132_pre_0000.nii.gz
# 🔧 Processing: VP133_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP133_post_0000.nii.gz
# ✅ Done: VP133_post_0000.nii.gz
# 🔧 Processing: VP133_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP133_pre_0000.nii.gz
# ✅ Done: VP133_pre_0000.nii.gz
# 🔧 Processing: VP134_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP134_pre_0000.nii.gz
# ✅ Done: VP134_pre_0000.nii.gz
# 🔧 Processing: VP135_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP135_pre_0000.nii.gz
# ✅ Done: VP135_pre_0000.nii.gz
# 🔧 Processing: VP136_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP136_post_0000.nii.gz
# ✅ Done: VP136_post_0000.nii.gz
# 🔧 Processing: VP136_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP136_pre_0000.nii.gz
# ✅ Done: VP136_pre_0000.nii.gz
# 🔧 Processing: VP137_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP137_post_0000.nii.gz
# ✅ Done: VP137_post_0000.nii.gz
# 🔧 Processing: VP137_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP137_pre_0000.nii.gz
# ✅ Done: VP137_pre_0000.nii.gz
# 🔧 Processing: VP138_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP138_post_0000.nii.gz
# ✅ Done: VP138_post_0000.nii.gz
# 🔧 Processing: VP138_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP138_pre_0000.nii.gz
# ✅ Done: VP138_pre_0000.nii.gz
# 🔧 Processing: VP139_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP139_post_0000.nii.gz
# ✅ Done: VP139_post_0000.nii.gz
# 🔧 Processing: VP139_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP139_pre_0000.nii.gz
# ✅ Done: VP139_pre_0000.nii.gz
# 🔧 Processing: VP140_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP140_post_0000.nii.gz
# ✅ Done: VP140_post_0000.nii.gz
# 🔧 Processing: VP140_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP140_pre_0000.nii.gz
# ✅ Done: VP140_pre_0000.nii.gz
# 🔧 Processing: VP141_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP141_post_0000.nii.gz
# ✅ Done: VP141_post_0000.nii.gz
# 🔧 Processing: VP141_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP141_pre_0000.nii.gz
# ✅ Done: VP141_pre_0000.nii.gz
# 🔧 Processing: VP142_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP142_post_0000.nii.gz
# ✅ Done: VP142_post_0000.nii.gz
# 🔧 Processing: VP142_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP142_pre_0000.nii.gz
# ✅ Done: VP142_pre_0000.nii.gz
# 🔧 Processing: VP143_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP143_post_0000.nii.gz
# ✅ Done: VP143_post_0000.nii.gz
# 🔧 Processing: VP143_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP143_pre_0000.nii.gz
# ✅ Done: VP143_pre_0000.nii.gz
# 🔧 Processing: VP144_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP144_post_0000.nii.gz
# ✅ Done: VP144_post_0000.nii.gz
# 🔧 Processing: VP144_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP144_pre_0000.nii.gz
# ✅ Done: VP144_pre_0000.nii.gz
# 🔧 Processing: VP145_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP145_post_0000.nii.gz
# ✅ Done: VP145_post_0000.nii.gz
# 🔧 Processing: VP145_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP145_pre_0000.nii.gz
# ✅ Done: VP145_pre_0000.nii.gz
# 🔧 Processing: VP146_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP146_post_0000.nii.gz
# ✅ Done: VP146_post_0000.nii.gz
# 🔧 Processing: VP146_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP146_pre_0000.nii.gz
# ✅ Done: VP146_pre_0000.nii.gz
# 🔧 Processing: VP147_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP147_post_0000.nii.gz
# ✅ Done: VP147_post_0000.nii.gz
# 🔧 Processing: VP147_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP147_pre_0000.nii.gz
# ✅ Done: VP147_pre_0000.nii.gz
# 🔧 Processing: VP148_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP148_post_0000.nii.gz
# ✅ Done: VP148_post_0000.nii.gz
# 🔧 Processing: VP148_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP148_pre_0000.nii.gz
# ✅ Done: VP148_pre_0000.nii.gz
# 🔧 Processing: VP149_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP149_pre_0000.nii.gz
# ✅ Done: VP149_pre_0000.nii.gz
# 🔧 Processing: VP150_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP150_pre_0000.nii.gz
# ✅ Done: VP150_pre_0000.nii.gz
# 🔧 Processing: VP151_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP151_post_0000.nii.gz
# ✅ Done: VP151_post_0000.nii.gz
# 🔧 Processing: VP151_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP151_pre_0000.nii.gz
# ✅ Done: VP151_pre_0000.nii.gz
# 🔧 Processing: VP152_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP152_post_0000.nii.gz
# ✅ Done: VP152_post_0000.nii.gz
# 🔧 Processing: VP152_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP152_pre_0000.nii.gz
# ✅ Done: VP152_pre_0000.nii.gz
# 🔧 Processing: VP153_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP153_pre_0000.nii.gz
# ✅ Done: VP153_pre_0000.nii.gz
# 🔧 Processing: VP154_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP154_post_0000.nii.gz
# ✅ Done: VP154_post_0000.nii.gz
# 🔧 Processing: VP154_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP154_pre_0000.nii.gz
# ✅ Done: VP154_pre_0000.nii.gz
# 🔧 Processing: VP155_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP155_post_0000.nii.gz
# ✅ Done: VP155_post_0000.nii.gz
# 🔧 Processing: VP155_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP155_pre_0000.nii.gz
# ✅ Done: VP155_pre_0000.nii.gz
# 🔧 Processing: VP156_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP156_post_0000.nii.gz
# ✅ Done: VP156_post_0000.nii.gz
# 🔧 Processing: VP156_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP156_pre_0000.nii.gz
# ✅ Done: VP156_pre_0000.nii.gz
# 🔧 Processing: VP157_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP157_post_0000.nii.gz
# ✅ Done: VP157_post_0000.nii.gz
# 🔧 Processing: VP157_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP157_pre_0000.nii.gz
# ✅ Done: VP157_pre_0000.nii.gz
# 🔧 Processing: VP158_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP158_pre_0000.nii.gz
# ✅ Done: VP158_pre_0000.nii.gz
# 🔧 Processing: VP159_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP159_post_0000.nii.gz
# ✅ Done: VP159_post_0000.nii.gz
# 🔧 Processing: VP159_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP159_pre_0000.nii.gz
# ✅ Done: VP159_pre_0000.nii.gz
# 🔧 Processing: VP160_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP160_pre_0000.nii.gz
# ✅ Done: VP160_pre_0000.nii.gz
# 🔧 Processing: VP161_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP161_post_0000.nii.gz
# ✅ Done: VP161_post_0000.nii.gz
# 🔧 Processing: VP161_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP161_pre_0000.nii.gz
# ✅ Done: VP161_pre_0000.nii.gz
# 🔧 Processing: VP162_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP162_post_0000.nii.gz
# ✅ Done: VP162_post_0000.nii.gz
# 🔧 Processing: VP162_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP162_pre_0000.nii.gz
# ✅ Done: VP162_pre_0000.nii.gz
# 🔧 Processing: VP163_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP163_post_0000.nii.gz
# ✅ Done: VP163_post_0000.nii.gz
# 🔧 Processing: VP163_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP163_pre_0000.nii.gz
# ✅ Done: VP163_pre_0000.nii.gz
# 🔧 Processing: VP164_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP164_post_0000.nii.gz
# ✅ Done: VP164_post_0000.nii.gz
# 🔧 Processing: VP164_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP164_pre_0000.nii.gz
# ✅ Done: VP164_pre_0000.nii.gz
# 🔧 Processing: VP165_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP165_pre_0000.nii.gz
# ✅ Done: VP165_pre_0000.nii.gz
# 🔧 Processing: VP167_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP167_post_0000.nii.gz
# ✅ Done: VP167_post_0000.nii.gz
# 🔧 Processing: VP167_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP167_pre_0000.nii.gz
# ✅ Done: VP167_pre_0000.nii.gz
# 🔧 Processing: VP168_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP168_post_0000.nii.gz
# ✅ Done: VP168_post_0000.nii.gz
# 🔧 Processing: VP168_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP168_pre_0000.nii.gz
# ✅ Done: VP168_pre_0000.nii.gz
# 🔧 Processing: VP169_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP169_post_0000.nii.gz
# ✅ Done: VP169_post_0000.nii.gz
# 🔧 Processing: VP169_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP169_pre_0000.nii.gz
# ✅ Done: VP169_pre_0000.nii.gz
# 🔧 Processing: VP170_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP170_pre_0000.nii.gz
# ✅ Done: VP170_pre_0000.nii.gz
# 🔧 Processing: VP171_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP171_post_0000.nii.gz
# ✅ Done: VP171_post_0000.nii.gz
# 🔧 Processing: VP171_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP171_pre_0000.nii.gz
# ✅ Done: VP171_pre_0000.nii.gz
# 🔧 Processing: VP172_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP172_post_0000.nii.gz
# ✅ Done: VP172_post_0000.nii.gz
# 🔧 Processing: VP172_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP172_pre_0000.nii.gz
# ✅ Done: VP172_pre_0000.nii.gz
# 🔧 Processing: VP173_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP173_post_0000.nii.gz
# ✅ Done: VP173_post_0000.nii.gz
# 🔧 Processing: VP173_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP173_pre_0000.nii.gz
# ✅ Done: VP173_pre_0000.nii.gz
# 🔧 Processing: VP174_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP174_post_0000.nii.gz
# ✅ Done: VP174_post_0000.nii.gz
# 🔧 Processing: VP174_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP174_pre_0000.nii.gz
# ✅ Done: VP174_pre_0000.nii.gz
# 🔧 Processing: VP175_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP175_post_0000.nii.gz
# ✅ Done: VP175_post_0000.nii.gz
# 🔧 Processing: VP175_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP175_pre_0000.nii.gz
# ✅ Done: VP175_pre_0000.nii.gz
# 🔧 Processing: VP176_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP176_post_0000.nii.gz
# ✅ Done: VP176_post_0000.nii.gz
# 🔧 Processing: VP176_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP176_pre_0000.nii.gz
# ✅ Done: VP176_pre_0000.nii.gz
# 🔧 Processing: VP177_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP177_post_0000.nii.gz
# ✅ Done: VP177_post_0000.nii.gz
# 🔧 Processing: VP177_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP177_pre_0000.nii.gz
# ✅ Done: VP177_pre_0000.nii.gz
# 🔧 Processing: VP178_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP178_post_0000.nii.gz
# ✅ Done: VP178_post_0000.nii.gz
# 🔧 Processing: VP178_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP178_pre_0000.nii.gz
# ✅ Done: VP178_pre_0000.nii.gz
# 🔧 Processing: VP179_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP179_post_0000.nii.gz
# ✅ Done: VP179_post_0000.nii.gz
# 🔧 Processing: VP179_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP179_pre_0000.nii.gz
# ✅ Done: VP179_pre_0000.nii.gz
# 🔧 Processing: VP180_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP180_post_0000.nii.gz
# ✅ Done: VP180_post_0000.nii.gz
# 🔧 Processing: VP180_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP180_pre_0000.nii.gz
# ✅ Done: VP180_pre_0000.nii.gz
# 🔧 Processing: VP181_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP181_post_0000.nii.gz
# ✅ Done: VP181_post_0000.nii.gz
# 🔧 Processing: VP181_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP181_pre_0000.nii.gz
# ✅ Done: VP181_pre_0000.nii.gz
# 🔧 Processing: VP183_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP183_post_0000.nii.gz
# ✅ Done: VP183_post_0000.nii.gz
# 🔧 Processing: VP183_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP183_pre_0000.nii.gz
# ✅ Done: VP183_pre_0000.nii.gz
# 🔧 Processing: VP184_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP184_post_0000.nii.gz
# ✅ Done: VP184_post_0000.nii.gz
# 🔧 Processing: VP184_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP184_pre_0000.nii.gz
# ✅ Done: VP184_pre_0000.nii.gz
# 🔧 Processing: VP185_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP185_post_0000.nii.gz
# ✅ Done: VP185_post_0000.nii.gz
# 🔧 Processing: VP185_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP185_pre_0000.nii.gz
# ✅ Done: VP185_pre_0000.nii.gz
# 🔧 Processing: VP186_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP186_post_0000.nii.gz
# ✅ Done: VP186_post_0000.nii.gz
# 🔧 Processing: VP186_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP186_pre_0000.nii.gz
# ✅ Done: VP186_pre_0000.nii.gz
# 🔧 Processing: VP187_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP187_post_0000.nii.gz
# ✅ Done: VP187_post_0000.nii.gz
# 🔧 Processing: VP187_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP187_pre_0000.nii.gz
# ✅ Done: VP187_pre_0000.nii.gz
# 🔧 Processing: VP188_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP188_pre_0000.nii.gz
# ✅ Done: VP188_pre_0000.nii.gz
# 🔧 Processing: VP189_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP189_post_0000.nii.gz
# ✅ Done: VP189_post_0000.nii.gz
# 🔧 Processing: VP189_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP189_pre_0000.nii.gz
# ✅ Done: VP189_pre_0000.nii.gz
# 🔧 Processing: VP190_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP190_post_0000.nii.gz
# ✅ Done: VP190_post_0000.nii.gz
# 🔧 Processing: VP190_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP190_pre_0000.nii.gz
# ✅ Done: VP190_pre_0000.nii.gz
# 🔧 Processing: VP191_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP191_post_0000.nii.gz
# ✅ Done: VP191_post_0000.nii.gz
# 🔧 Processing: VP191_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP191_pre_0000.nii.gz
# ✅ Done: VP191_pre_0000.nii.gz
# 🔧 Processing: VP192_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP192_pre_0000.nii.gz
# ✅ Done: VP192_pre_0000.nii.gz
# 🔧 Processing: VP193_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP193_post_0000.nii.gz
# ✅ Done: VP193_post_0000.nii.gz
# 🔧 Processing: VP193_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP193_pre_0000.nii.gz
# ✅ Done: VP193_pre_0000.nii.gz
# 🔧 Processing: VP194_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP194_post_0000.nii.gz
# ✅ Done: VP194_post_0000.nii.gz
# 🔧 Processing: VP194_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP194_pre_0000.nii.gz
# ✅ Done: VP194_pre_0000.nii.gz
# 🔧 Processing: VP195_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP195_post_0000.nii.gz
# ✅ Done: VP195_post_0000.nii.gz
# 🔧 Processing: VP195_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP195_pre_0000.nii.gz
# ✅ Done: VP195_pre_0000.nii.gz
# 🔧 Processing: VP196_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP196_post_0000.nii.gz
# ✅ Done: VP196_post_0000.nii.gz
# 🔧 Processing: VP196_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP196_pre_0000.nii.gz
# ✅ Done: VP196_pre_0000.nii.gz
# 🔧 Processing: VP197_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP197_post_0000.nii.gz
# ✅ Done: VP197_post_0000.nii.gz
# 🔧 Processing: VP197_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP197_pre_0000.nii.gz
# ✅ Done: VP197_pre_0000.nii.gz
# 🔧 Processing: VP198_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP198_post_0000.nii.gz
# ✅ Done: VP198_post_0000.nii.gz
# 🔧 Processing: VP198_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP198_pre_0000.nii.gz
# ✅ Done: VP198_pre_0000.nii.gz
# 🔧 Processing: VP199_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP199_post_0000.nii.gz
# ✅ Done: VP199_post_0000.nii.gz
# 🔧 Processing: VP199_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP199_pre_0000.nii.gz
# ✅ Done: VP199_pre_0000.nii.gz
# 🔧 Processing: VP200_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP200_post_0000.nii.gz
# ✅ Done: VP200_post_0000.nii.gz
# 🔧 Processing: VP200_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP200_pre_0000.nii.gz
# ✅ Done: VP200_pre_0000.nii.gz
# 🔧 Processing: VP201_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP201_pre_0000.nii.gz
# ✅ Done: VP201_pre_0000.nii.gz
# 🔧 Processing: VP202_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP202_post_0000.nii.gz
# ✅ Done: VP202_post_0000.nii.gz
# 🔧 Processing: VP202_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP202_pre_0000.nii.gz
# ✅ Done: VP202_pre_0000.nii.gz
# 🔧 Processing: VP203_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP203_post_0000.nii.gz
# ✅ Done: VP203_post_0000.nii.gz
# 🔧 Processing: VP203_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP203_pre_0000.nii.gz
# ✅ Done: VP203_pre_0000.nii.gz
# 🔧 Processing: VP204_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP204_post_0000.nii.gz
# ✅ Done: VP204_post_0000.nii.gz
# 🔧 Processing: VP204_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP204_pre_0000.nii.gz
# ✅ Done: VP204_pre_0000.nii.gz
# 🔧 Processing: VP205_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP205_post_0000.nii.gz
# ✅ Done: VP205_post_0000.nii.gz
# 🔧 Processing: VP205_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP205_pre_0000.nii.gz
# ✅ Done: VP205_pre_0000.nii.gz
# 🔧 Processing: VP206_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP206_post_0000.nii.gz
# ✅ Done: VP206_post_0000.nii.gz
# 🔧 Processing: VP206_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP206_pre_0000.nii.gz
# ✅ Done: VP206_pre_0000.nii.gz
# 🔧 Processing: VP207_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP207_post_0000.nii.gz
# ✅ Done: VP207_post_0000.nii.gz
# 🔧 Processing: VP207_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP207_pre_0000.nii.gz
# ✅ Done: VP207_pre_0000.nii.gz
# 🔧 Processing: VP208_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP208_pre_0000.nii.gz
# ✅ Done: VP208_pre_0000.nii.gz
# 🔧 Processing: VP209_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP209_post_0000.nii.gz
# ✅ Done: VP209_post_0000.nii.gz
# 🔧 Processing: VP209_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP209_pre_0000.nii.gz
# ✅ Done: VP209_pre_0000.nii.gz
# 🔧 Processing: VP210_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP210_post_0000.nii.gz
# ✅ Done: VP210_post_0000.nii.gz
# 🔧 Processing: VP210_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP210_pre_0000.nii.gz
# ✅ Done: VP210_pre_0000.nii.gz
# 🔧 Processing: VP211_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP211_pre_0000.nii.gz
# ✅ Done: VP211_pre_0000.nii.gz
# 🔧 Processing: VP212_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP212_post_0000.nii.gz
# ✅ Done: VP212_post_0000.nii.gz
# 🔧 Processing: VP212_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP212_pre_0000.nii.gz
# ✅ Done: VP212_pre_0000.nii.gz
# 🔧 Processing: VP213_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP213_post_0000.nii.gz
# ✅ Done: VP213_post_0000.nii.gz
# 🔧 Processing: VP213_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP213_pre_0000.nii.gz
# ✅ Done: VP213_pre_0000.nii.gz
# 🔧 Processing: VP214_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP214_post_0000.nii.gz
# ✅ Done: VP214_post_0000.nii.gz
# 🔧 Processing: VP214_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP214_pre_0000.nii.gz
# ✅ Done: VP214_pre_0000.nii.gz
# 🔧 Processing: VP215_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP215_post_0000.nii.gz
# ✅ Done: VP215_post_0000.nii.gz
# 🔧 Processing: VP215_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP215_pre_0000.nii.gz
# ✅ Done: VP215_pre_0000.nii.gz
# 🔧 Processing: VP216_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP216_post_0000.nii.gz
# ✅ Done: VP216_post_0000.nii.gz
# 🔧 Processing: VP216_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP216_pre_0000.nii.gz
# ✅ Done: VP216_pre_0000.nii.gz
# 🔧 Processing: VP217_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP217_pre_0000.nii.gz
# ✅ Done: VP217_pre_0000.nii.gz
# 🔧 Processing: VP218_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP218_post_0000.nii.gz
# ✅ Done: VP218_post_0000.nii.gz
# 🔧 Processing: VP218_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP218_pre_0000.nii.gz
# ✅ Done: VP218_pre_0000.nii.gz
# 🔧 Processing: VP219_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP219_post_0000.nii.gz
# ✅ Done: VP219_post_0000.nii.gz
# 🔧 Processing: VP219_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP219_pre_0000.nii.gz
# ✅ Done: VP219_pre_0000.nii.gz
# 🔧 Processing: VP220_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP220_post_0000.nii.gz
# ✅ Done: VP220_post_0000.nii.gz
# 🔧 Processing: VP220_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP220_pre_0000.nii.gz
# ✅ Done: VP220_pre_0000.nii.gz
# 🔧 Processing: VP221_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP221_post_0000.nii.gz
# ✅ Done: VP221_post_0000.nii.gz
# 🔧 Processing: VP221_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP221_pre_0000.nii.gz
# ✅ Done: VP221_pre_0000.nii.gz
# 🔧 Processing: VP222_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP222_post_0000.nii.gz
# ✅ Done: VP222_post_0000.nii.gz
# 🔧 Processing: VP222_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP222_pre_0000.nii.gz
# ✅ Done: VP222_pre_0000.nii.gz
# 🔧 Processing: VP224_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP224_pre_0000.nii.gz
# ✅ Done: VP224_pre_0000.nii.gz
# 🔧 Processing: VP225_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP225_post_0000.nii.gz
# ✅ Done: VP225_post_0000.nii.gz
# 🔧 Processing: VP225_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP225_pre_0000.nii.gz
# ✅ Done: VP225_pre_0000.nii.gz
# 🔧 Processing: VP226_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP226_post_0000.nii.gz
# ✅ Done: VP226_post_0000.nii.gz
# 🔧 Processing: VP226_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP226_pre_0000.nii.gz
# ✅ Done: VP226_pre_0000.nii.gz
# 🔧 Processing: VP227_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP227_post_0000.nii.gz
# ✅ Done: VP227_post_0000.nii.gz
# 🔧 Processing: VP227_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP227_pre_0000.nii.gz
# ✅ Done: VP227_pre_0000.nii.gz
# 🔧 Processing: VP228_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP228_post_0000.nii.gz
# ✅ Done: VP228_post_0000.nii.gz
# 🔧 Processing: VP228_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP228_pre_0000.nii.gz
# ✅ Done: VP228_pre_0000.nii.gz
# 🔧 Processing: VP229_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP229_post_0000.nii.gz
# ✅ Done: VP229_post_0000.nii.gz
# 🔧 Processing: VP229_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP229_pre_0000.nii.gz
# ✅ Done: VP229_pre_0000.nii.gz
# 🔧 Processing: VP230_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP230_post_0000.nii.gz
# ✅ Done: VP230_post_0000.nii.gz
# 🔧 Processing: VP230_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP230_pre_0000.nii.gz
# ✅ Done: VP230_pre_0000.nii.gz
# 🔧 Processing: VP231_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP231_post_0000.nii.gz
# ✅ Done: VP231_post_0000.nii.gz
# 🔧 Processing: VP231_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP231_pre_0000.nii.gz
# ✅ Done: VP231_pre_0000.nii.gz
# 🔧 Processing: VP232_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP232_post_0000.nii.gz
# ✅ Done: VP232_post_0000.nii.gz
# 🔧 Processing: VP232_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP232_pre_0000.nii.gz
# ✅ Done: VP232_pre_0000.nii.gz
# 🔧 Processing: VP233_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP233_post_0000.nii.gz
# ✅ Done: VP233_post_0000.nii.gz
# 🔧 Processing: VP233_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP233_pre_0000.nii.gz
# ✅ Done: VP233_pre_0000.nii.gz
# 🔧 Processing: VP234_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP234_post_0000.nii.gz
# ✅ Done: VP234_post_0000.nii.gz
# 🔧 Processing: VP234_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP234_pre_0000.nii.gz
# ✅ Done: VP234_pre_0000.nii.gz
# 🔧 Processing: VP235_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP235_post_0000.nii.gz
# ✅ Done: VP235_post_0000.nii.gz
# 🔧 Processing: VP235_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP235_pre_0000.nii.gz
# ✅ Done: VP235_pre_0000.nii.gz
# 🔧 Processing: VP236_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP236_post_0000.nii.gz
# ✅ Done: VP236_post_0000.nii.gz
# 🔧 Processing: VP236_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP236_pre_0000.nii.gz
# ✅ Done: VP236_pre_0000.nii.gz
# 🔧 Processing: VP237_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP237_post_0000.nii.gz
# ✅ Done: VP237_post_0000.nii.gz
# 🔧 Processing: VP237_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP237_pre_0000.nii.gz
# ✅ Done: VP237_pre_0000.nii.gz
# 🔧 Processing: VP238_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP238_post_0000.nii.gz
# ✅ Done: VP238_post_0000.nii.gz
# 🔧 Processing: VP238_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP238_pre_0000.nii.gz
# ...
# ⚡ Using cached bias corrected: VP413_pre_0000.nii.gz
# ✅ Done: VP413_pre_0000.nii.gz
# 🔧 Processing: VP414_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP414_post_0000.nii.gz
# ✅ Done: VP414_post_0000.nii.gz
# 🔧 Processing: VP414_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP414_pre_0000.nii.gz
# ✅ Done: VP414_pre_0000.nii.gz
# 🔧 Processing: VP415_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP415_post_0000.nii.gz
# ✅ Done: VP415_post_0000.nii.gz
# 🔧 Processing: VP415_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP415_pre_0000.nii.gz
# ✅ Done: VP415_pre_0000.nii.gz
# 🔧 Processing: VP416_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP416_post_0000.nii.gz
# ✅ Done: VP416_post_0000.nii.gz
# 🔧 Processing: VP417_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP417_post_0000.nii.gz
# ✅ Done: VP417_post_0000.nii.gz
# 🔧 Processing: VP417_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP417_pre_0000.nii.gz
# ✅ Done: VP417_pre_0000.nii.gz
# 🔧 Processing: VP418_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP418_post_0000.nii.gz
# ✅ Done: VP418_post_0000.nii.gz
# 🔧 Processing: VP418_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP418_pre_0000.nii.gz
# ✅ Done: VP418_pre_0000.nii.gz
# 🔧 Processing: VP419_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP419_post_0000.nii.gz
# ✅ Done: VP419_post_0000.nii.gz
# 🔧 Processing: VP419_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP419_pre_0000.nii.gz
# ✅ Done: VP419_pre_0000.nii.gz
# 🔧 Processing: VP420_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP420_post_0000.nii.gz
# ✅ Done: VP420_post_0000.nii.gz
# 🔧 Processing: VP420_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP420_pre_0000.nii.gz
# ✅ Done: VP420_pre_0000.nii.gz
# 🔧 Processing: VP421_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP421_post_0000.nii.gz
# ✅ Done: VP421_post_0000.nii.gz
# 🔧 Processing: VP421_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP421_pre_0000.nii.gz
# ✅ Done: VP421_pre_0000.nii.gz
# 🔧 Processing: VP422_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP422_post_0000.nii.gz
# ✅ Done: VP422_post_0000.nii.gz
# 🔧 Processing: VP422_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP422_pre_0000.nii.gz
# ✅ Done: VP422_pre_0000.nii.gz
# 🔧 Processing: VP423_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP423_post_0000.nii.gz
# ✅ Done: VP423_post_0000.nii.gz
# 🔧 Processing: VP423_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP423_pre_0000.nii.gz
# ✅ Done: VP423_pre_0000.nii.gz
# 🔧 Processing: VP424_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP424_post_0000.nii.gz
# ✅ Done: VP424_post_0000.nii.gz
# 🔧 Processing: VP424_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP424_pre_0000.nii.gz
# ✅ Done: VP424_pre_0000.nii.gz
# 🔧 Processing: VP425_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP425_post_0000.nii.gz
# ✅ Done: VP425_post_0000.nii.gz
# 🔧 Processing: VP425_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP425_pre_0000.nii.gz
# ✅ Done: VP425_pre_0000.nii.gz
# 🔧 Processing: VP426_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP426_post_0000.nii.gz
# ✅ Done: VP426_post_0000.nii.gz
# 🔧 Processing: VP426_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP426_pre_0000.nii.gz
# ✅ Done: VP426_pre_0000.nii.gz
# 🔧 Processing: VP427_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP427_post_0000.nii.gz
# ✅ Done: VP427_post_0000.nii.gz
# 🔧 Processing: VP427_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP427_pre_0000.nii.gz
# ✅ Done: VP427_pre_0000.nii.gz
# 🔧 Processing: VP428_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP428_pre_0000.nii.gz
# ✅ Done: VP428_pre_0000.nii.gz
# 🔧 Processing: VP429_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP429_post_0000.nii.gz
# ✅ Done: VP429_post_0000.nii.gz
# 🔧 Processing: VP429_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP429_pre_0000.nii.gz
# ✅ Done: VP429_pre_0000.nii.gz
# 🔧 Processing: VP430_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP430_post_0000.nii.gz
# ✅ Done: VP430_post_0000.nii.gz
# 🔧 Processing: VP430_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP430_pre_0000.nii.gz
# ✅ Done: VP430_pre_0000.nii.gz
# 🔧 Processing: VP431_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP431_post_0000.nii.gz
# ✅ Done: VP431_post_0000.nii.gz
# 🔧 Processing: VP431_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP431_pre_0000.nii.gz
# ✅ Done: VP431_pre_0000.nii.gz
# 🔧 Processing: VP432_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP432_post_0000.nii.gz
# ✅ Done: VP432_post_0000.nii.gz
# 🔧 Processing: VP432_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP432_pre_0000.nii.gz
# ✅ Done: VP432_pre_0000.nii.gz
# 🔧 Processing: VP433_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP433_post_0000.nii.gz
# ✅ Done: VP433_post_0000.nii.gz
# 🔧 Processing: VP433_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP433_pre_0000.nii.gz
# ✅ Done: VP433_pre_0000.nii.gz
# 🔧 Processing: VP434_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP434_post_0000.nii.gz
# ✅ Done: VP434_post_0000.nii.gz
# 🔧 Processing: VP434_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP434_pre_0000.nii.gz
# ✅ Done: VP434_pre_0000.nii.gz
# 🔧 Processing: VP435_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP435_post_0000.nii.gz
# ✅ Done: VP435_post_0000.nii.gz
# 🔧 Processing: VP435_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP435_pre_0000.nii.gz
# ✅ Done: VP435_pre_0000.nii.gz
# 🔧 Processing: VP436_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP436_post_0000.nii.gz
# ✅ Done: VP436_post_0000.nii.gz
# 🔧 Processing: VP436_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP436_pre_0000.nii.gz
# ✅ Done: VP436_pre_0000.nii.gz
# 🔧 Processing: VP437_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP437_post_0000.nii.gz
# ✅ Done: VP437_post_0000.nii.gz
# 🔧 Processing: VP437_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP437_pre_0000.nii.gz
# ✅ Done: VP437_pre_0000.nii.gz
# 🔧 Processing: VP438_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP438_post_0000.nii.gz
# ✅ Done: VP438_post_0000.nii.gz
# 🔧 Processing: VP438_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP438_pre_0000.nii.gz
# ✅ Done: VP438_pre_0000.nii.gz
# 🔧 Processing: VP439_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP439_post_0000.nii.gz
# ✅ Done: VP439_post_0000.nii.gz
# 🔧 Processing: VP439_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP439_pre_0000.nii.gz
# ✅ Done: VP439_pre_0000.nii.gz
# 🔧 Processing: VP440_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP440_post_0000.nii.gz
# ✅ Done: VP440_post_0000.nii.gz
# 🔧 Processing: VP440_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP440_pre_0000.nii.gz
# ✅ Done: VP440_pre_0000.nii.gz
# 🔧 Processing: VP441_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP441_post_0000.nii.gz
# ✅ Done: VP441_post_0000.nii.gz
# 🔧 Processing: VP441_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP441_pre_0000.nii.gz
# ✅ Done: VP441_pre_0000.nii.gz
# 🔧 Processing: VP442_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP442_post_0000.nii.gz
# ✅ Done: VP442_post_0000.nii.gz
# 🔧 Processing: VP442_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP442_pre_0000.nii.gz
# ✅ Done: VP442_pre_0000.nii.gz
# 🔧 Processing: VP443_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP443_post_0000.nii.gz
# ✅ Done: VP443_post_0000.nii.gz
# 🔧 Processing: VP443_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP443_pre_0000.nii.gz
# ✅ Done: VP443_pre_0000.nii.gz
# 🔧 Processing: VP444_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP444_post_0000.nii.gz
# ✅ Done: VP444_post_0000.nii.gz
# 🔧 Processing: VP444_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP444_pre_0000.nii.gz
# ✅ Done: VP444_pre_0000.nii.gz
# 🔧 Processing: VP446_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP446_post_0000.nii.gz
# ✅ Done: VP446_post_0000.nii.gz
# 🔧 Processing: VP446_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP446_pre_0000.nii.gz
# ✅ Done: VP446_pre_0000.nii.gz
# 🔧 Processing: VP447_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP447_post_0000.nii.gz
# ✅ Done: VP447_post_0000.nii.gz
# 🔧 Processing: VP447_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP447_pre_0000.nii.gz
# ✅ Done: VP447_pre_0000.nii.gz
# 🔧 Processing: VP448_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP448_post_0000.nii.gz
# ✅ Done: VP448_post_0000.nii.gz
# 🔧 Processing: VP448_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP448_pre_0000.nii.gz
# ✅ Done: VP448_pre_0000.nii.gz
# 🔧 Processing: VP449_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP449_post_0000.nii.gz
# ✅ Done: VP449_post_0000.nii.gz
# 🔧 Processing: VP449_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP449_pre_0000.nii.gz
# ✅ Done: VP449_pre_0000.nii.gz
# 🔧 Processing: VP450_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP450_post_0000.nii.gz
# ✅ Done: VP450_post_0000.nii.gz
# 🔧 Processing: VP450_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP450_pre_0000.nii.gz
# ✅ Done: VP450_pre_0000.nii.gz
# 🔧 Processing: VP451_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP451_post_0000.nii.gz
# ✅ Done: VP451_post_0000.nii.gz
# 🔧 Processing: VP451_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP451_pre_0000.nii.gz
# ✅ Done: VP451_pre_0000.nii.gz
# 🔧 Processing: VP452_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP452_post_0000.nii.gz
# ✅ Done: VP452_post_0000.nii.gz
# 🔧 Processing: VP452_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP452_pre_0000.nii.gz
# ✅ Done: VP452_pre_0000.nii.gz
# 🔧 Processing: VP453_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP453_post_0000.nii.gz
# ✅ Done: VP453_post_0000.nii.gz
# 🔧 Processing: VP453_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP453_pre_0000.nii.gz
# ✅ Done: VP453_pre_0000.nii.gz
# 🔧 Processing: VP454_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP454_post_0000.nii.gz
# ✅ Done: VP454_post_0000.nii.gz
# 🔧 Processing: VP454_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP454_pre_0000.nii.gz
# ✅ Done: VP454_pre_0000.nii.gz
# 🔧 Processing: VP455_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP455_post_0000.nii.gz
# ✅ Done: VP455_post_0000.nii.gz
# 🔧 Processing: VP455_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP455_pre_0000.nii.gz
# ✅ Done: VP455_pre_0000.nii.gz
# 🔧 Processing: VP456_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP456_post_0000.nii.gz
# ✅ Done: VP456_post_0000.nii.gz
# 🔧 Processing: VP456_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP456_pre_0000.nii.gz
# ✅ Done: VP456_pre_0000.nii.gz
# 🔧 Processing: VP457_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP457_post_0000.nii.gz
# ✅ Done: VP457_post_0000.nii.gz
# 🔧 Processing: VP457_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP457_pre_0000.nii.gz
# ✅ Done: VP457_pre_0000.nii.gz
# 🔧 Processing: VP458_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP458_post_0000.nii.gz
# ✅ Done: VP458_post_0000.nii.gz
# 🔧 Processing: VP458_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP458_pre_0000.nii.gz
# ✅ Done: VP458_pre_0000.nii.gz
# 🔧 Processing: VP459_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP459_post_0000.nii.gz
# ✅ Done: VP459_post_0000.nii.gz
# 🔧 Processing: VP459_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP459_pre_0000.nii.gz
# ✅ Done: VP459_pre_0000.nii.gz
# 🔧 Processing: VP460_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP460_post_0000.nii.gz
# ✅ Done: VP460_post_0000.nii.gz
# 🔧 Processing: VP460_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP460_pre_0000.nii.gz
# ✅ Done: VP460_pre_0000.nii.gz
# 🔧 Processing: VP461_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP461_post_0000.nii.gz
# ✅ Done: VP461_post_0000.nii.gz
# 🔧 Processing: VP461_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP461_pre_0000.nii.gz
# ✅ Done: VP461_pre_0000.nii.gz
# 🔧 Processing: VP462_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP462_post_0000.nii.gz
# ✅ Done: VP462_post_0000.nii.gz
# 🔧 Processing: VP462_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP462_pre_0000.nii.gz
# ✅ Done: VP462_pre_0000.nii.gz
# 🔧 Processing: VP463_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP463_post_0000.nii.gz
# ✅ Done: VP463_post_0000.nii.gz
# 🔧 Processing: VP463_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP463_pre_0000.nii.gz
# ✅ Done: VP463_pre_0000.nii.gz
# 🔧 Processing: VP464_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP464_post_0000.nii.gz
# ✅ Done: VP464_post_0000.nii.gz
# 🔧 Processing: VP464_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP464_pre_0000.nii.gz
# ✅ Done: VP464_pre_0000.nii.gz
# 🔧 Processing: VP465_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP465_post_0000.nii.gz
# ✅ Done: VP465_post_0000.nii.gz
# 🔧 Processing: VP465_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP465_pre_0000.nii.gz
# ✅ Done: VP465_pre_0000.nii.gz
# 🔧 Processing: VP466_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP466_post_0000.nii.gz
# ✅ Done: VP466_post_0000.nii.gz
# 🔧 Processing: VP466_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP466_pre_0000.nii.gz
# ✅ Done: VP466_pre_0000.nii.gz
# 🔧 Processing: VP467_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP467_post_0000.nii.gz
# ✅ Done: VP467_post_0000.nii.gz
# 🔧 Processing: VP467_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP467_pre_0000.nii.gz
# ✅ Done: VP467_pre_0000.nii.gz
# 🔧 Processing: VP468_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP468_post_0000.nii.gz
# ✅ Done: VP468_post_0000.nii.gz
# 🔧 Processing: VP468_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP468_pre_0000.nii.gz
# ✅ Done: VP468_pre_0000.nii.gz
# 🔧 Processing: VP469_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP469_post_0000.nii.gz
# ✅ Done: VP469_post_0000.nii.gz
# 🔧 Processing: VP469_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP469_pre_0000.nii.gz
# ✅ Done: VP469_pre_0000.nii.gz
# 🔧 Processing: VP470_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP470_post_0000.nii.gz
# ✅ Done: VP470_post_0000.nii.gz
# 🔧 Processing: VP470_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP470_pre_0000.nii.gz
# ✅ Done: VP470_pre_0000.nii.gz
# 🔧 Processing: VP471_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP471_post_0000.nii.gz
# ✅ Done: VP471_post_0000.nii.gz
# 🔧 Processing: VP471_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP471_pre_0000.nii.gz
# ✅ Done: VP471_pre_0000.nii.gz
# 🔧 Processing: VP472_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP472_post_0000.nii.gz
# ✅ Done: VP472_post_0000.nii.gz
# 🔧 Processing: VP472_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP472_pre_0000.nii.gz
# ✅ Done: VP472_pre_0000.nii.gz
# 🔧 Processing: VP473_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP473_post_0000.nii.gz
# ✅ Done: VP473_post_0000.nii.gz
# 🔧 Processing: VP473_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP473_pre_0000.nii.gz
# ✅ Done: VP473_pre_0000.nii.gz
# 🔧 Processing: VP474_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP474_post_0000.nii.gz
# ✅ Done: VP474_post_0000.nii.gz
# 🔧 Processing: VP474_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP474_pre_0000.nii.gz
# ✅ Done: VP474_pre_0000.nii.gz
# 🔧 Processing: VP475_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP475_post_0000.nii.gz
# ✅ Done: VP475_post_0000.nii.gz
# 🔧 Processing: VP475_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP475_pre_0000.nii.gz
# ✅ Done: VP475_pre_0000.nii.gz
# 🔧 Processing: VP476_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP476_post_0000.nii.gz
# ✅ Done: VP476_post_0000.nii.gz
# 🔧 Processing: VP476_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP476_pre_0000.nii.gz
# ✅ Done: VP476_pre_0000.nii.gz
# 🔧 Processing: VP477_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP477_post_0000.nii.gz
# ✅ Done: VP477_post_0000.nii.gz
# 🔧 Processing: VP477_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP477_pre_0000.nii.gz
# ✅ Done: VP477_pre_0000.nii.gz
# 🔧 Processing: VP478_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP478_post_0000.nii.gz
# ✅ Done: VP478_post_0000.nii.gz
# 🔧 Processing: VP478_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP478_pre_0000.nii.gz
# ✅ Done: VP478_pre_0000.nii.gz
# 🔧 Processing: VP479_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP479_post_0000.nii.gz
# ✅ Done: VP479_post_0000.nii.gz
# 🔧 Processing: VP479_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP479_pre_0000.nii.gz
# ✅ Done: VP479_pre_0000.nii.gz
# 🔧 Processing: VP480_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP480_post_0000.nii.gz
# ✅ Done: VP480_post_0000.nii.gz
# 🔧 Processing: VP480_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP480_pre_0000.nii.gz
# ✅ Done: VP480_pre_0000.nii.gz
# 🔧 Processing: VP481_post_0000.nii.gz
# ⚡ Using cached bias corrected: VP481_post_0000.nii.gz
# ✅ Done: VP481_post_0000.nii.gz
# 🔧 Processing: VP481_pre_0000.nii.gz
# ⚡ Using cached bias corrected: VP481_pre_0000.nii.gz
# ✅ Done: VP481_pre_0000.nii.gz

# %%
import os
import SimpleITK as sitk
import numpy as np

image_dir = "./image_data/images"
mask_dir = "./image_data/masks"
output_image_dir = "./image_data/output_196/images"
output_mask_dir = "./image_data/output_196/masks"
cache_dir = "./image_data/n4_cache"

os.makedirs(output_image_dir, exist_ok=True)
os.makedirs(output_mask_dir, exist_ok=True)
os.makedirs(cache_dir, exist_ok=True)

# ⚙️ 기준 spacing 및 shape (골반 전체 포함하도록 확대)
TARGET_SPACING = [1.0, 1.0, 1.0]
TARGET_SHAPE = (128, 196, 196)


# ✅ Bias field correction with caching
def bias_field_correction_cached(image, fname):
    cached_path = os.path.join(cache_dir, fname)
    if os.path.exists(cached_path):
        print(f"⚡ Using cached bias corrected: {fname}")
        return sitk.ReadImage(cached_path)

    image = sitk.Cast(image, sitk.sitkFloat32)
    mask = sitk.OtsuThreshold(image, 0, 1, 200)
    corrector = sitk.N4BiasFieldCorrectionImageFilter()
    corrected = corrector.Execute(image, mask)
    sitk.WriteImage(corrected, cached_path)
    print(f"✅ Cached bias corrected: {fname}")
    return corrected

# ✅ Z-score normalization
def normalize_image(itk_image):
    image_np = sitk.GetArrayFromImage(itk_image).astype(np.float32)
    nonzero = image_np[image_np > 0]
    if nonzero.size == 0:
        return itk_image
    mean, std = np.mean(nonzero), np.std(nonzero)
    normalized = (image_np - mean) / (std + 1e-8)
    normalized[image_np == 0] = 0
    norm_image = sitk.GetImageFromArray(normalized.astype(np.float32))
    norm_image.CopyInformation(itk_image)
    return norm_image

# ✅ Resampling
def resample_image(itk_image, is_label=False):
    original_spacing = itk_image.GetSpacing()
    original_size = itk_image.GetSize()
    new_size = [
        int(round(osz * ospc / tspc))
        for osz, ospc, tspc in zip(original_size, original_spacing, TARGET_SPACING)
    ]
    resampler = sitk.ResampleImageFilter()
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_label else sitk.sitkLinear)
    resampler.SetOutputSpacing(TARGET_SPACING)
    resampler.SetSize(new_size)
    resampler.SetOutputDirection(itk_image.GetDirection())
    resampler.SetOutputOrigin(itk_image.GetOrigin())
    resampler.SetDefaultPixelValue(0)
    return resampler.Execute(itk_image)

# ✅ Padding or cropping
def pad_or_crop(image_np, target_shape):
    current_shape = image_np.shape
    pad_width = [(0, max(t - c, 0)) for c, t in zip(current_shape, target_shape)]
    padded = np.pad(image_np, pad_width, mode='constant')
    cropped = padded[:target_shape[0], :target_shape[1], :target_shape[2]]
    return cropped

# 🔁 메인 루프
for fname in sorted(os.listdir(image_dir)):
    if not fname.endswith(".nii.gz") or fname in exclude_files:
        continue

    image_path = os.path.join(image_dir, fname)
    mask_path = os.path.join(mask_dir, fname)

    if not os.path.exists(mask_path):
        print(f"❌ Mask not found for {fname}")
        continue

    try:
        print(f"🔧 Processing: {fname}")

        # 1. Load
        image = sitk.ReadImage(image_path)
        mask = sitk.ReadImage(mask_path)

        # 2. Bias field correction (with cache)
        image = bias_field_correction_cached(image, fname)

        # 3. Z-score normalization
        image = normalize_image(image)

        # 4. Resample
        image_resampled = resample_image(image, is_label=False)
        mask_resampled = resample_image(mask, is_label=True)

        # 5. Pad or crop
        image_np = sitk.GetArrayFromImage(image_resampled).astype(np.float32)
        mask_np = sitk.GetArrayFromImage(mask_resampled).astype(np.uint8)

        image_fixed = pad_or_crop(image_np, TARGET_SHAPE)
        mask_fixed = pad_or_crop(mask_np, TARGET_SHAPE)

        # 6. Convert back to image
        image_out = sitk.GetImageFromArray(image_fixed)
        mask_out = sitk.GetImageFromArray(mask_fixed)

        # 7. Set metadata
        image_out.SetSpacing(TARGET_SPACING)
        image_out.SetOrigin(image_resampled.GetOrigin())
        image_out.SetDirection(image_resampled.GetDirection())

        mask_out.SetSpacing(TARGET_SPACING)
        mask_out.SetOrigin(image_resampled.GetOrigin())
        mask_out.SetDirection(image_resampled.GetDirection())

        # 8. Save
        sitk.WriteImage(image_out, os.path.join(output_image_dir, fname))
        sitk.WriteImage(mask_out, os.path.join(output_mask_dir, fname))
        print(f"✅ Done: {fname}")

    except Exception as e:
        print(f"❌ Failed {fname}: {e}")

# %% [markdown]
# 단계	전처리 내용	설명
# 1️⃣	Bias Field Correction	N4 알고리즘으로 intensity non-uniformity 제거 캐싱추가
# 2️⃣	Intensity Clipping	이상치 제거 (0.5~99.5 percentile)
# 3️⃣	Z-score Normalization	background 제외하고 평균 0, 표준편차 1로 정규화
# 4️⃣	Resampling	spacing → [1.0, 1.0, 1.0], 마스크는 NN
# 5️⃣	Pad or Crop	shape
# 6️⃣	Affine 정보 유지	origin, spacing, direction 포함
